# %%
import sys
import os

top='E:\\工作\\工作日志'
for root, dirnames, filenames in os.walk(top):
    #print(filename)
    for file in filenames:
        filename=os.path.join(root,file)
        with open(filename) as f:
            for line in f:
                print('='*10 + file.split('.')[-2] + '='*10)
                #print fi
                #print(line)
# Out:
# ==========20110630==========
# ==========20110630==========
# ==========20110630==========
# ==========20110630==========
# ==========20110630==========
# ==========20110630==========
# ==========20110630==========
# ==========20110630==========
# ==========20110630==========
# ==========20110630==========
# ==========20110701==========
# ==========20110701==========
# ==========20110701==========
# ==========20110701==========
# ==========20110701==========
# ==========20110701==========
# ==========20110701==========
# ==========20110701==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ==========20110705==========
# ...
