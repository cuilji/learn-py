# %%
import pandas as pd

df = pd.read_excel('downloads\\test.xls')
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']

#df.plot(kind='line')

# %%
# %pylab inline
df.plot(x='Date', y='Price', kind='line')
# Out:
# Populating the interactive namespace from numpy and matplotlib
